# %% [markdown]
# <a href="https://colab.research.google.com/github/pablex72/operations-load-time-series/blob/main/loading_shp_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Initialize geopandas
# !pip install geopandas
import geopandas as gpd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 42.4 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 51.1 MB/s
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_buildings_a_free_1.shx"
polygons = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons.plot()

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_buildings_a_free_1.shx"
polygons = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons.plot()

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_landuse_a_free_1.shp"
polygons1 = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons1.plot()

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.shx"
polygons = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons.plot()
# Out:
# ERROR:fiona._env:Unable to open /content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.shp or /content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.SHP.
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open /content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.shp or /content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.SHP.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-19-bc617123ab1e> in <module>
#       1 #Read the shapefile with the land parcels
#       2 polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_natural_a_free_1.shx"
# ...

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_places_a_free_1.shx"
polygons = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons.plot()

# %%
#Read the shapefile with the land parcels
polygonspath = "/content/drive/MyDrive/Colab Notebooks/gis_osm_pofw_a_free_1.shx"
polygons = gpd.read_file(polygonspath)

#Plot it to check this is what we're expecting
polygons.plot()
